# %%
import json
import subprocess
import re
import os
import pandas as pd

# %%
owner = "2dot71mily"
repo = "toy_repo"
gh_repo_base = f"/repos/{owner}/{repo}"
output_data_dir = "output_data"
local_path = os.path.join(os.getcwd(), output_data_dir)

# %%
api_cmd_json_template = """gh api \
   -H "Accept: application/vnd.github+json" \
   -H "X-GitHub-Api-Version: 2022-11-28" \
    {cmd}?per_page=100"""


api_cmd_patch_template = """gh api \
   -H "Accept: application/vnd.github.v3.patch" \
   -H "X-GitHub-Api-Version: 2022-11-28" \
    {cmd}?per_page=100"""

# %%
html_commit_template = f"https://github.com/{owner}/{repo}/commit/{{sha}}"

event_cmd = f"{gh_repo_base}/events"
event_output_filename = f"{repo}_events.json"

commits_cmd_template = f"{gh_repo_base}/commits/{{sha}}"
commit_output_filename_template = f"{repo}_{{prefix}}_{{sha}}.patch"

pr_commits_cmd_template = f"{gh_repo_base}/pulls/{{pr}}/commits"
pr_output_filename_template = f"{repo}_pull_{{pr}}_commits.json"

checkruns_cmd_template = f"{gh_repo_base}/commits/{{sha}}/check-runs"
checkruns_output_filename_template = f"{repo}_pull_{{sha}}_checkruns.json"

# %%
def create_directory(directory_path):
    if not os.path.exists(directory_path):
        os.makedirs(directory_path)


def get_cleaned_gh_cmd_output(
    cmd,
    output_filename,
    api_cmd_template=api_cmd_json_template,
    output_path=local_path,
    max_display_len=2000,
    verbose=False,
):
    gh_cmd = api_cmd_template.format(cmd=cmd)
    result = subprocess.run(gh_cmd, shell=True, capture_output=True, text=True)

    # Remove ANSI escape codes
    ansi_escape = re.compile(r"\x1B(?:[@-Z\\-_]|\[[0-?]*[ -/]*[@-~])")
    clean_output = ansi_escape.sub("", result.stdout)

    create_directory(output_path)
    with open(os.path.join(output_path, output_filename), "w") as f:
        f.write(clean_output)

    if verbose:
        print(clean_output[:max_display_len])
        if len(clean_output) > max_display_len:
            print("<truncated>\n")

        print(f"Output written to {output_filename}\n\n")

    return clean_output

# %% [markdown]
# ## Get all GitHub API Events from repo

# %%
event_json = get_cleaned_gh_cmd_output(
    f"{gh_repo_base}/events", f"{repo}_events.json", verbose=False
)
event_data = json.loads(event_json)

# %% [markdown]
# ## Reload Event data into Pandas for post processing

# %%
data_df = pd.read_json(
    os.path.join(local_path, event_output_filename), orient="records"
)
len(data_df)
# Out:
# 10

# %% [markdown]
# ## Take a quick looks at the Event data overall and EventTypes captured

# %%
data_df.head(3)
# Out:
#             id              type  \
# 0  41323740523         PushEvent
# 1  41323740434  PullRequestEvent
# 2  41323737085  PullRequestEvent
#
#                                                actor  \
# 0  {'id': 21292059, 'login': '2dot71mily', 'displ...
# 1  {'id': 21292059, 'login': '2dot71mily', 'displ...
# 2  {'id': 21292059, 'login': '2dot71mily', 'displ...
#
#                                                 repo  \
# 0  {'id': 847491164, 'name': '2dot71mily/toy_repo...
# 1  {'id': 847491164, 'name': '2dot71mily/toy_repo...
# 2  {'id': 847491164, 'name': '2dot71mily/toy_repo...
#
#                                              payload  public  \
# 0  {'repository_id': 847491164, 'push_id': 199272...    True
# 1  {'action': 'closed', 'number': 2, 'pull_reques...    True
# 2  {'action': 'opened', 'number': 2, 'pull_reques...    True
#
#                  created_at
# 0 2024-08-26 00:47:58+00:00
# 1 2024-08-26 00:47:58+00:00
# 2 2024-08-26 00:47:42+00:00

# %%
data_df.type.value_counts()
# Out:
# type
# PullRequestEvent    4
# CreateEvent         4
# PushEvent           2
# Name: count, dtype: int64

# %%
data_by_type = {
    event_type: data_df[data_df.type == event_type]
    for event_type in data_df.type.unique().tolist()
}

# %% [markdown]
# ## Checking PullRequestEvents first

# %%
shas = {}
for i, pr_event in data_by_type["PullRequestEvent"].iterrows():
    print(f" ******** PR{pr_event.payload['number']} pr_event iter {i} ******** ")
    shas["merge_commit"] = pr_event.payload["pull_request"]["merge_commit_sha"]
    shas["head"] = pr_event.payload["pull_request"]["head"]["sha"]
    shas["base"] = pr_event.payload["pull_request"]["base"]["sha"]

    for commit_type, sha in shas.items():
        print(f"{commit_type}: {html_commit_template.format(sha=sha)}")
        try:
            out = get_cleaned_gh_cmd_output(
                commits_cmd_template.format(sha=sha),
                output_filename=commit_output_filename_template.format(
                    prefix=f"pr_event_{commit_type}_commit", sha=sha
                ),
                api_cmd_template=api_cmd_patch_template,
                verbose=True,
            )
        except Exception as e:
            print(f"Failed to retrieve data for sha: {sha}")
            print(e)
            continue
# Out:
#  ******** PR2 pr_event iter 1 ********
# merge_commit: https://github.com/2dot71mily/toy_repo/commit/a4f9fa6f698db44e1c44e065aca87e73773d2742
# From a4f9fa6f698db44e1c44e065aca87e73773d2742 Mon Sep 17 00:00:00 2001
# From: Emily McMilin <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 17:47:57 -0700
# Subject: [PATCH] B (#2)
#
# * 3
#
# * del 3
#
# * 4
# ---
#  README.md | 1 +
#  1 file changed, 1 insertion(+)
#
# diff --git a/README.md b/README.md
# index 4539bbf..7f2f028 100644
# --- a/README.md
# +++ b/README.md
# @@ -1,3 +1,4 @@
#  0
#  1
#  2
# +4
# \ No newline at end of file
#
# Output written to toy_repo_pr_event_merge_commit_commit_a4f9fa6f698db44e1c44e065aca87e73773d2742.patch
#
#
# head: https://github.com/2dot71mily/toy_repo/commit/673b77704f9908888716050414131ae3878d0a28
# From 673b77704f9908888716050414131ae3878d0a28 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 17:47:00 -0700
# Subject: [PATCH] 4
#
# ---
#  README.md | 1 +
#  1 file changed, 1 insertion(+)
#
# diff --git a/README.md b/README.md
# index 4539bbf..7f2f028 100644
# --- a/README.md
# +++ b/README.md
# @@ -1,3 +1,4 @@
#  0
#  1
#  2
# +4
# \ No newline at end of file
#
# Output written to toy_repo_pr_event_head_commit_673b77704f9908888716050414131ae3878d0a28.patch
#
#
# base: https://github.com/2dot71mily/toy_repo/commit/8616102c03051b57d5d64c9cb3488207298b4c41
# From 137552281732197116438c69031d265f036dd3ce Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 17:43:36 -0700
# Subject: [PATCH 1/3] 0
#
# ---
#  README.md | 1 +
#  1 file changed, 1 insertion(+)
#
# diff --git a/README.md b/README.md
# index e69de29..573541a 100644
# --- a/README.md
# +++ b/README.md
# @@ -0,0 +1 @@
# +0
#
# From 818e3e46edc91dceb2d3ee545cc71310a175720f Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 17:44:07 -0700
# Subject: [PATCH 2/3] 1
#
# ---
#  README.md | 1 +
#  1 file changed, 1 insertion(+)
#
# diff --git a/README.md b/README.md
# index 573541a..0d66ea1 100644
# --- a/README.md
# +++ b/README.md
# @@ -1 +1,2 @@
#  0
# +1
#
# From 786d2503f66e5a747723b747e692a0d8c4abfb74 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 17:44:25 -0700
# Subject: [PATCH 3/3] 2
#
# ---
#  README.md | 1 +
#  1 file changed, 1 insertion(+)
#
# diff --git a/README.md b/README.md
# index 0d66ea1..4539bbf 100644
# --- a/README.md
# +++ b/README.md
# @@ -1,2 +1,3 @@
#  0
#  1
# +2
#
# Output written to toy_repo_pr_event_base_commit_8616102c03051b57d5d64c9cb3488207298b4c41.patch
#
#
#  ******** PR2 pr_event iter 2 ********
# merge_commit: https://github.com/2dot71mily/toy_repo/commit/None
# {
#   "message": "No commit found for SHA: None",
#   "documentation_url": "https://docs.github.com/rest/commits/commits#get-a-commit",
#   "status": "422"
# }
#
# Output written to toy_repo_pr_event_merge_commit_commit_None.patch
#
#
# head: https://github.com/2dot71mily/toy_repo/commit/673b77704f9908888716050414131ae3878d0a28
# From 673b77704f9908888716050414131ae3878d0a28 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 17:47:00 -0700
# Subject: [PATCH] 4
#
# ---
#  README.md | 1 +
#  1 file changed, 1 insertion(+)
#
# diff --git a/README.md b/README.md
# index 4539bbf..7f2f028 100644
# --- a/README.md
# +++ b/README.md
# @@ -1,3 +1,4 @@
#  0
#  1
#  2
# +4
# \ No newline at end of file
#
# Output written to toy_repo_pr_event_head_commit_673b77704f9908888716050414131ae3878d0a28.patch
#
#
# base: https://github.com/2dot71mily/toy_repo/commit/8616102c03051b57d5d64c9cb3488207298b4c41
# From 137552281732197116438c69031d265f036dd3ce Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 17:43:36 -0700
# Subject: [PATCH 1/3] 0
#
# ---
#  README.md | 1 +
#  1 file changed, 1 insertion(+)
#
# diff --git a/README.md b/README.md
# index e69de29..573541a 100644
# --- a/README.md
# +++ b/README.md
# @@ -0,0 +1 @@
# +0
#
# From 818e3e46edc91dceb2d3ee545cc71310a175720f Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 17:44:07 -0700
# Subject: [PATCH 2/3] 1
#
# ---
#  README.md | 1 +
#  1 file changed, 1 insertion(+)
#
# diff --git a/README.md b/README.md
# index 573541a..0d66ea1 100644
# --- a/README.md
# +++ b/README.md
# @@ -1 +1,2 @@
#  0
# +1
#
# From 786d2503f66e5a747723b747e692a0d8c4abfb74 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 17:44:25 -0700
# Subject: [PATCH 3/3] 2
#
# ---
#  README.md | 1 +
#  1 file changed, 1 insertion(+)
#
# diff --git a/README.md b/README.md
# index 0d66ea1..4539bbf 100644
# --- a/README.md
# +++ b/README.md
# @@ -1,2 +1,3 @@
#  0
#  1
# +2
#
# Output written to toy_repo_pr_event_base_commit_8616102c03051b57d5d64c9cb3488207298b4c41.patch
#
#
#  ******** PR1 pr_event iter 5 ********
# merge_commit: https://github.com/2dot71mily/toy_repo/commit/8616102c03051b57d5d64c9cb3488207298b4c41
# From 137552281732197116438c69031d265f036dd3ce Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 17:43:36 -0700
# Subject: [PATCH 1/3] 0
#
# ---
#  README.md | 1 +
#  1 file changed, 1 insertion(+)
#
# diff --git a/README.md b/README.md
# index e69de29..573541a 100644
# --- a/README.md
# +++ b/README.md
# @@ -0,0 +1 @@
# +0
#
# From 818e3e46edc91dceb2d3ee545cc71310a175720f Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 17:44:07 -0700
# Subject: [PATCH 2/3] 1
#
# ---
#  README.md | 1 +
#  1 file changed, 1 insertion(+)
#
# diff --git a/README.md b/README.md
# index 573541a..0d66ea1 100644
# --- a/README.md
# +++ b/README.md
# @@ -1 +1,2 @@
#  0
# +1
#
# From 786d2503f66e5a747723b747e692a0d8c4abfb74 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 17:44:25 -0700
# Subject: [PATCH 3/3] 2
#
# ---
#  README.md | 1 +
#  1 file changed, 1 insertion(+)
#
# diff --git a/README.md b/README.md
# index 0d66ea1..4539bbf 100644
# --- a/README.md
# +++ b/README.md
# @@ -1,2 +1,3 @@
#  0
#  1
# +2
#
# Output written to toy_repo_pr_event_merge_commit_commit_8616102c03051b57d5d64c9cb3488207298b4c41.patch
#
#
# head: https://github.com/2dot71mily/toy_repo/commit/786d2503f66e5a747723b747e692a0d8c4abfb74
# From 786d2503f66e5a747723b747e692a0d8c4abfb74 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 17:44:25 -0700
# Subject: [PATCH] 2
#
# ---
#  README.md | 1 +
#  1 file changed, 1 insertion(+)
#
# diff --git a/README.md b/README.md
# index 0d66ea1..4539bbf 100644
# --- a/README.md
# +++ b/README.md
# @@ -1,2 +1,3 @@
#  0
#  1
# +2
#
# Output written to toy_repo_pr_event_head_commit_786d2503f66e5a747723b747e692a0d8c4abfb74.patch
#
#
# base: https://github.com/2dot71mily/toy_repo/commit/81e1e29014f8abf2bb762ca0bf76f4f5e02b4272
# From 81e1e29014f8abf2bb762ca0bf76f4f5e02b4272 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 17:42:11 -0700
# Subject: [PATCH] init
#
# ---
#  README.md | 0
#  1 file changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 README.md
#
# diff --git a/README.md b/README.md
# new file mode 100644
# index 0000000..e69de29
#
# Output written to toy_repo_pr_event_base_commit_81e1e29014f8abf2bb762ca0bf76f4f5e02b4272.patch
#
#
#  ******** PR1 pr_event iter 6 ********
# merge_commit: https://github.com/2dot71mily/toy_repo/commit/None
# {
#   "message": "No commit found for SHA: None",
#   "documentation_url": "https://docs.github.com/rest/commits/commits#get-a-commit",
#   "status": "422"
# }
#
# Output written to toy_repo_pr_event_merge_commit_commit_None.patch
#
#
# head: https://github.com/2dot71mily/toy_repo/commit/786d2503f66e5a747723b747e692a0d8c4abfb74
# From 786d2503f66e5a747723b747e692a0d8c4abfb74 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 17:44:25 -0700
# Subject: [PATCH] 2
#
# ---
#  README.md | 1 +
#  1 file changed, 1 insertion(+)
#
# diff --git a/README.md b/README.md
# index 0d66ea1..4539bbf 100644
# --- a/README.md
# +++ b/README.md
# @@ -1,2 +1,3 @@
#  0
#  1
# +2
#
# Output written to toy_repo_pr_event_head_commit_786d2503f66e5a747723b747e692a0d8c4abfb74.patch
#
#
# base: https://github.com/2dot71mily/toy_repo/commit/81e1e29014f8abf2bb762ca0bf76f4f5e02b4272
# From 81e1e29014f8abf2bb762ca0bf76f4f5e02b4272 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 17:42:11 -0700
# Subject: [PATCH] init
#
# ---
#  README.md | 0
#  1 file changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 README.md
#
# diff --git a/README.md b/README.md
# new file mode 100644
# index 0000000..e69de29
#
# Output written to toy_repo_pr_event_base_commit_81e1e29014f8abf2bb762ca0bf76f4f5e02b4272.patch

# %% [markdown]
# ## Checking PushEvents as well

# %%
for i, push_event in data_by_type["PushEvent"].iterrows():
    print(f" ******** PushEvent iter {i} ******** ")
    for j, commit in enumerate(push_event.payload["commits"]):
        sha = commit["sha"]
        print(f"commit {j}: {html_commit_template.format(sha=sha)}")
        try:
            get_cleaned_gh_cmd_output(
                commits_cmd_template.format(sha=sha),
                output_filename=commit_output_filename_template.format(
                    prefix=f"push_event_{i}_commit_{j}", sha=sha
                ),
                api_cmd_template=api_cmd_patch_template,
                verbose=True,
            )
        except Exception as e:
            print(f"Failed to retrieve data for sha: {sha}")
            print(e)
            continue
# Out:
#  ******** PushEvent iter 0 ********
# commit 0: https://github.com/2dot71mily/toy_repo/commit/a4f9fa6f698db44e1c44e065aca87e73773d2742
# From a4f9fa6f698db44e1c44e065aca87e73773d2742 Mon Sep 17 00:00:00 2001
# From: Emily McMilin <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 17:47:57 -0700
# Subject: [PATCH] B (#2)
#
# * 3
#
# * del 3
#
# * 4
# ---
#  README.md | 1 +
#  1 file changed, 1 insertion(+)
#
# diff --git a/README.md b/README.md
# index 4539bbf..7f2f028 100644
# --- a/README.md
# +++ b/README.md
# @@ -1,3 +1,4 @@
#  0
#  1
#  2
# +4
# \ No newline at end of file
#
# Output written to toy_repo_push_event_0_commit_0_a4f9fa6f698db44e1c44e065aca87e73773d2742.patch
#
#
#  ******** PushEvent iter 4 ********
# commit 0: https://github.com/2dot71mily/toy_repo/commit/137552281732197116438c69031d265f036dd3ce
# From 137552281732197116438c69031d265f036dd3ce Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 17:43:36 -0700
# Subject: [PATCH] 0
#
# ---
#  README.md | 1 +
#  1 file changed, 1 insertion(+)
#
# diff --git a/README.md b/README.md
# index e69de29..573541a 100644
# --- a/README.md
# +++ b/README.md
# @@ -0,0 +1 @@
# +0
#
# Output written to toy_repo_push_event_4_commit_0_137552281732197116438c69031d265f036dd3ce.patch
#
#
# commit 1: https://github.com/2dot71mily/toy_repo/commit/818e3e46edc91dceb2d3ee545cc71310a175720f
# From 818e3e46edc91dceb2d3ee545cc71310a175720f Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 17:44:07 -0700
# Subject: [PATCH] 1
#
# ---
#  README.md | 1 +
#  1 file changed, 1 insertion(+)
#
# diff --git a/README.md b/README.md
# index 573541a..0d66ea1 100644
# --- a/README.md
# +++ b/README.md
# @@ -1 +1,2 @@
#  0
# +1
#
# Output written to toy_repo_push_event_4_commit_1_818e3e46edc91dceb2d3ee545cc71310a175720f.patch
#
#
# commit 2: https://github.com/2dot71mily/toy_repo/commit/786d2503f66e5a747723b747e692a0d8c4abfb74
# From 786d2503f66e5a747723b747e692a0d8c4abfb74 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 17:44:25 -0700
# Subject: [PATCH] 2
#
# ---
#  README.md | 1 +
#  1 file changed, 1 insertion(+)
#
# diff --git a/README.md b/README.md
# index 0d66ea1..4539bbf 100644
# --- a/README.md
# +++ b/README.md
# @@ -1,2 +1,3 @@
#  0
#  1
# +2
#
# Output written to toy_repo_push_event_4_commit_2_786d2503f66e5a747723b747e692a0d8c4abfb74.patch
#
#
# commit 3: https://github.com/2dot71mily/toy_repo/commit/8616102c03051b57d5d64c9cb3488207298b4c41
# From 137552281732197116438c69031d265f036dd3ce Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 17:43:36 -0700
# Subject: [PATCH 1/3] 0
#
# ---
#  README.md | 1 +
#  1 file changed, 1 insertion(+)
#
# diff --git a/README.md b/README.md
# index e69de29..573541a 100644
# --- a/README.md
# +++ b/README.md
# @@ -0,0 +1 @@
# +0
#
# From 818e3e46edc91dceb2d3ee545cc71310a175720f Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 17:44:07 -0700
# Subject: [PATCH 2/3] 1
#
# ---
#  README.md | 1 +
#  1 file changed, 1 insertion(+)
#
# diff --git a/README.md b/README.md
# index 573541a..0d66ea1 100644
# --- a/README.md
# +++ b/README.md
# @@ -1 +1,2 @@
#  0
# +1
#
# From 786d2503f66e5a747723b747e692a0d8c4abfb74 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 17:44:25 -0700
# Subject: [PATCH 3/3] 2
#
# ---
#  README.md | 1 +
#  1 file changed, 1 insertion(+)
#
# diff --git a/README.md b/README.md
# index 0d66ea1..4539bbf 100644
# --- a/README.md
# +++ b/README.md
# @@ -1,2 +1,3 @@
#  0
#  1
# +2
#
# Output written to toy_repo_push_event_4_commit_3_8616102c03051b57d5d64c9cb3488207298b4c41.patch

# %% [markdown]
# # PR sub-commits

# %%
# Exracting PR numbers from PullRequestEvents json to find PR sub-commits
unique_pr_numbers = {
    row.payload["number"] for _, row in data_by_type["PullRequestEvent"].iterrows()
}

# %%
for pr in unique_pr_numbers:
    print(f" ******** Processing PR: {pr} ******** ")
    print(f"https://github.com/{owner}/{repo}/pull/{pr}")
    pr_json = get_cleaned_gh_cmd_output(
        pr_commits_cmd_template.format(pr=pr),
        output_filename=pr_output_filename_template.format(pr=pr),
        api_cmd_template=api_cmd_json_template,
    )
    pr_data = json.loads(pr_json)
    for commit in pr_data:
        print(" ****** commit patch ****** ")
        sha = commit["sha"]
        print(f" **** Is commit sha in EventsAPI json? {sha in event_json} **** ")

        print("sha: ", sha)
        print("html_url: ", commit["html_url"])
        get_cleaned_gh_cmd_output(
            commits_cmd_template.format(sha=sha),
            output_filename=commit_output_filename_template.format(
                prefix=f"pr_{pr}", sha=sha
            ),
            api_cmd_template=api_cmd_patch_template,
            verbose=True,
        )

        print(" ****** commit checkrun? ****** ")
        get_cleaned_gh_cmd_output(
            checkruns_cmd_template.format(sha=sha),
            output_filename=checkruns_output_filename_template.format(sha=sha),
            api_cmd_template=api_cmd_json_template,
            verbose=True,
        )
# Out:
#  ******** Processing PR: 1 ********
# https://github.com/2dot71mily/toy_repo/pull/1
#  ****** commit patch ******
#  **** Is commit sha in EventsAPI json? True ****
# sha:  137552281732197116438c69031d265f036dd3ce
# html_url:  https://github.com/2dot71mily/toy_repo/commit/137552281732197116438c69031d265f036dd3ce
# From 137552281732197116438c69031d265f036dd3ce Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 17:43:36 -0700
# Subject: [PATCH] 0
#
# ---
#  README.md | 1 +
#  1 file changed, 1 insertion(+)
#
# diff --git a/README.md b/README.md
# index e69de29..573541a 100644
# --- a/README.md
# +++ b/README.md
# @@ -0,0 +1 @@
# +0
#
# Output written to toy_repo_pr_1_137552281732197116438c69031d265f036dd3ce.patch
#
#
#  ****** commit checkrun? ******
# {
#   "total_count": 0,
#   "check_runs": []
# }
#
# Output written to toy_repo_pull_137552281732197116438c69031d265f036dd3ce_checkruns.json
#
#
#  ****** commit patch ******
#  **** Is commit sha in EventsAPI json? True ****
# sha:  818e3e46edc91dceb2d3ee545cc71310a175720f
# html_url:  https://github.com/2dot71mily/toy_repo/commit/818e3e46edc91dceb2d3ee545cc71310a175720f
# From 818e3e46edc91dceb2d3ee545cc71310a175720f Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 17:44:07 -0700
# Subject: [PATCH] 1
#
# ---
#  README.md | 1 +
#  1 file changed, 1 insertion(+)
#
# diff --git a/README.md b/README.md
# index 573541a..0d66ea1 100644
# --- a/README.md
# +++ b/README.md
# @@ -1 +1,2 @@
#  0
# +1
#
# Output written to toy_repo_pr_1_818e3e46edc91dceb2d3ee545cc71310a175720f.patch
#
#
#  ****** commit checkrun? ******
# {
#   "total_count": 0,
#   "check_runs": []
# }
#
# Output written to toy_repo_pull_818e3e46edc91dceb2d3ee545cc71310a175720f_checkruns.json
#
#
#  ****** commit patch ******
#  **** Is commit sha in EventsAPI json? True ****
# sha:  786d2503f66e5a747723b747e692a0d8c4abfb74
# html_url:  https://github.com/2dot71mily/toy_repo/commit/786d2503f66e5a747723b747e692a0d8c4abfb74
# From 786d2503f66e5a747723b747e692a0d8c4abfb74 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 17:44:25 -0700
# Subject: [PATCH] 2
#
# ---
#  README.md | 1 +
#  1 file changed, 1 insertion(+)
#
# diff --git a/README.md b/README.md
# index 0d66ea1..4539bbf 100644
# --- a/README.md
# +++ b/README.md
# @@ -1,2 +1,3 @@
#  0
#  1
# +2
#
# Output written to toy_repo_pr_1_786d2503f66e5a747723b747e692a0d8c4abfb74.patch
#
#
#  ****** commit checkrun? ******
# {
#   "total_count": 0,
#   "check_runs": []
# }
#
# Output written to toy_repo_pull_786d2503f66e5a747723b747e692a0d8c4abfb74_checkruns.json
#
#
#  ******** Processing PR: 2 ********
# https://github.com/2dot71mily/toy_repo/pull/2
#  ****** commit patch ******
#  **** Is commit sha in EventsAPI json? False ****
# sha:  a42a4a626fc7931d38dbb318e28c9156aed5d01b
# html_url:  https://github.com/2dot71mily/toy_repo/commit/a42a4a626fc7931d38dbb318e28c9156aed5d01b
# From a42a4a626fc7931d38dbb318e28c9156aed5d01b Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 17:45:46 -0700
# Subject: [PATCH] 3
#
# ---
#  README.md | 1 +
#  1 file changed, 1 insertion(+)
#
# diff --git a/README.md b/README.md
# index 4539bbf..bc856da 100644
# --- a/README.md
# +++ b/README.md
# @@ -1,3 +1,4 @@
#  0
#  1
#  2
# +3
#
# Output written to toy_repo_pr_2_a42a4a626fc7931d38dbb318e28c9156aed5d01b.patch
#
#
#  ****** commit checkrun? ******
# {
#   "total_count": 0,
#   "check_runs": []
# }
#
# Output written to toy_repo_pull_a42a4a626fc7931d38dbb318e28c9156aed5d01b_checkruns.json
#
#
#  ****** commit patch ******
#  **** Is commit sha in EventsAPI json? False ****
# sha:  a376ddb4eaf782bfb339d9b4c1585a048622ad83
# html_url:  https://github.com/2dot71mily/toy_repo/commit/a376ddb4eaf782bfb339d9b4c1585a048622ad83
# From a376ddb4eaf782bfb339d9b4c1585a048622ad83 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 17:46:38 -0700
# Subject: [PATCH] del 3
#
# ---
#  README.md | 1 -
#  1 file changed, 1 deletion(-)
#
# diff --git a/README.md b/README.md
# index bc856da..4539bbf 100644
# --- a/README.md
# +++ b/README.md
# @@ -1,4 +1,3 @@
#  0
#  1
#  2
# -3
#
# Output written to toy_repo_pr_2_a376ddb4eaf782bfb339d9b4c1585a048622ad83.patch
#
#
#  ****** commit checkrun? ******
# {
#   "total_count": 0,
#   "check_runs": []
# }
#
# Output written to toy_repo_pull_a376ddb4eaf782bfb339d9b4c1585a048622ad83_checkruns.json
#
#
#  ****** commit patch ******
#  **** Is commit sha in EventsAPI json? True ****
# sha:  673b77704f9908888716050414131ae3878d0a28
# html_url:  https://github.com/2dot71mily/toy_repo/commit/673b77704f9908888716050414131ae3878d0a28
# From 673b77704f9908888716050414131ae3878d0a28 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 17:47:00 -0700
# Subject: [PATCH] 4
#
# ---
#  README.md | 1 +
#  1 file changed, 1 insertion(+)
#
# diff --git a/README.md b/README.md
# index 4539bbf..7f2f028 100644
# --- a/README.md
# +++ b/README.md
# @@ -1,3 +1,4 @@
#  0
#  1
#  2
# +4
# \ No newline at end of file
#
# Output written to toy_repo_pr_2_673b77704f9908888716050414131ae3878d0a28.patch
#
#
#  ****** commit checkrun? ******
# {
#   "total_count": 0,
#   "check_runs": []
# }
#
# Output written to toy_repo_pull_673b77704f9908888716050414131ae3878d0a28_checkruns.json
