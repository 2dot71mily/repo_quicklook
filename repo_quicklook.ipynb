# %%
import json
import subprocess
import re
import os
import pandas as pd

# %%
owner = "2dot71mily"
repo = "repo_baby"
gh_repo_base = f"/repos/{owner}/{repo}"
output_data_dir = "output_data"
local_path = os.path.join(os.getcwd(), output_data_dir)

# %%
api_cmd_json_template = """gh api \
   -H "Accept: application/vnd.github+json" \
   -H "X-GitHub-Api-Version: 2022-11-28" \
    {cmd}?per_page=100"""


api_cmd_patch_template = """gh api \
   -H "Accept: application/vnd.github.v3.patch" \
   -H "X-GitHub-Api-Version: 2022-11-28" \
    {cmd}?per_page=100"""

# %%
html_commit_template = f"https://github.com/{owner}/{repo}/commit/{{sha}}"

event_cmd = f"{gh_repo_base}/events"
event_output_filename = f"{repo}_events.json"

commits_cmd_template = f"{gh_repo_base}/commits/{{sha}}"
commit_output_filename_template = f"{repo}_{{prefix}}_{{sha}}.patch"

pr_commits_cmd_template = f"{gh_repo_base}/pulls/{{pr}}/commits"
pr_output_filename_template = f"{repo}_pull_{{pr}}_commits.json"

checkruns_cmd_template = f"{gh_repo_base}/commits/{{sha}}/check-runs"
checkruns_output_filename_template = f"{repo}_pull_{{sha}}_checkruns.json"

# %%
def create_directory(directory_path):
    if not os.path.exists(directory_path):
        os.makedirs(directory_path)


def get_cleaned_gh_cmd_output(
    cmd,
    output_filename,
    api_cmd_template=api_cmd_json_template,
    output_path=local_path,
    max_display_len=400,
    verbose=False,
):
    gh_cmd = api_cmd_template.format(cmd=cmd)
    result = subprocess.run(gh_cmd, shell=True, capture_output=True, text=True)

    # Remove ANSI escape codes
    ansi_escape = re.compile(r"\x1B(?:[@-Z\\-_]|\[[0-?]*[ -/]*[@-~])")
    clean_output = ansi_escape.sub("", result.stdout)

    create_directory(output_path)
    with open(os.path.join(output_path, output_filename), "w") as f:
        f.write(clean_output)

    if verbose:
        print(clean_output[:max_display_len])
        if len(clean_output) > max_display_len:
            print("<truncated>\n")

        print(f"Output written to {output_filename}\n\n")

    return clean_output

# %% [markdown]
# ## Get all GitHub API Events from repo

# %%
event_json = get_cleaned_gh_cmd_output(
    f"{gh_repo_base}/events", f"{repo}_events.json", verbose=False
)
event_data = json.loads(event_json)

# %% [markdown]
# ## Reload Event data into Pandas for post processing

# %%
data_df = pd.read_json(
    os.path.join(local_path, event_output_filename), orient="records"
)
len(data_df)
# Out:
# 35

# %% [markdown]
# ## Take a quick looks at the Event data overall and EventTypes captured

# %%
data_df.head(3)
# Out:
#             id              type  \
# 0  41327020234         PushEvent
# 1  41327020091  PullRequestEvent
# 2  41326983661         PushEvent
#
#                                                actor  \
# 0  {'id': 21292059, 'login': '2dot71mily', 'displ...
# 1  {'id': 21292059, 'login': '2dot71mily', 'displ...
# 2  {'id': 21292059, 'login': '2dot71mily', 'displ...
#
#                                                 repo  \
# 0  {'id': 846400152, 'name': '2dot71mily/repo_bab...
# 1  {'id': 846400152, 'name': '2dot71mily/repo_bab...
# 2  {'id': 846400152, 'name': '2dot71mily/repo_bab...
#
#                                              payload  public  \
# 0  {'repository_id': 846400152, 'push_id': 199289...    True
# 1  {'action': 'closed', 'number': 7, 'pull_reques...    True
# 2  {'repository_id': 846400152, 'push_id': 199289...    True
#
#                  created_at
# 0 2024-08-26 04:33:08+00:00
# 1 2024-08-26 04:33:07+00:00
# 2 2024-08-26 04:31:15+00:00

# %%
data_df.type.value_counts()
# Out:
# type
# PullRequestEvent    14
# PushEvent           11
# CreateEvent          9
# PublicEvent          1
# Name: count, dtype: int64

# %%
data_by_type = {
    event_type: data_df[data_df.type == event_type]
    for event_type in data_df.type.unique().tolist()
}

# %% [markdown]
# ## Checking PullRequestEvents first

# %%
shas = {}
for i, pr_event in data_by_type["PullRequestEvent"].iterrows():
    print(f" ******** PR{pr_event.payload['number']} pr_event iter {i} ******** ")
    shas["merge_commit"] = pr_event.payload["pull_request"]["merge_commit_sha"]
    shas["head"] = pr_event.payload["pull_request"]["head"]["sha"]
    shas["base"] = pr_event.payload["pull_request"]["base"]["sha"]

    for commit_type, sha in shas.items():
        print(f"{commit_type}: {html_commit_template.format(sha=sha)}")
        try:
            out = get_cleaned_gh_cmd_output(
                commits_cmd_template.format(sha=sha),
                output_filename=commit_output_filename_template.format(
                    prefix=f"pr_event_{commit_type}_commit", sha=sha
                ),
                api_cmd_template=api_cmd_patch_template,
                verbose=True,
            )
        except Exception as e:
            print(f"Failed to retrieve data for sha: {sha}")
            print(e)
            continue
# Out:
#  ******** PR7 pr_event iter 1 ********
# merge_commit: https://github.com/2dot71mily/repo_baby/commit/e8e3e3560a80eecc68ab5439fc67d82030ba0083
# From e8e3e3560a80eecc68ab5439fc67d82030ba0083 Mon Sep 17 00:00:00 2001
# From: Emily McMilin <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 21:33:06 -0700
# Subject: [PATCH] add workflow (#7)
#
# * add workflow
#
# * add logistic regression
#
# * add test logistic regression
#
# * add e2e
#
# * add e2e test
# ---
#  .github/workflows/python-app.yml | 39 +++++++++++++++++++++++++++
#  e2e_logistic_regression.py       | 4
# <truncated>
#
# Output written to repo_baby_pr_event_merge_commit_commit_e8e3e3560a80eecc68ab5439fc67d82030ba0083.patch
#
#
# head: https://github.com/2dot71mily/repo_baby/commit/58f63591312000428772626e100c6c801d0d4ea0
# From 58f63591312000428772626e100c6c801d0d4ea0 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 21:31:11 -0700
# Subject: [PATCH] add e2e test
#
# ---
#  test_e2e_logistic_regression.py | 6 ++++++
#  1 file changed, 6 insertions(+)
#  create mode 100644 test_e2e_logistic_regression.py
#
# diff --git a/test_e2e_logistic_regression.py b/test_e2e_logistic_regression.py
# new file
# <truncated>
#
# Output written to repo_baby_pr_event_head_commit_58f63591312000428772626e100c6c801d0d4ea0.patch
#
#
# base: https://github.com/2dot71mily/repo_baby/commit/d82a833b896ee0bb684db799a8d06e4320b3586e
# From d82a833b896ee0bb684db799a8d06e4320b3586e Mon Sep 17 00:00:00 2001
# From: Emily McMilin <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:44:46 -0700
# Subject: [PATCH] mod readme (#6)
#
# ---
#  README.md | 9 +++++++++
#  1 file changed, 9 insertions(+)
#
# diff --git a/README.md b/README.md
# index 8bc8734..b608cb0 100644
# --- a/README.md
# +++ b/README.md
# @@ -1 +1,10 @@
#  # repo_baby
# +
# +This main dir is fun
# <truncated>
#
# Output written to repo_baby_pr_event_base_commit_d82a833b896ee0bb684db799a8d06e4320b3586e.patch
#
#
#  ******** PR7 pr_event iter 4 ********
# merge_commit: https://github.com/2dot71mily/repo_baby/commit/None
# {
#   "message": "No commit found for SHA: None",
#   "documentation_url": "https://docs.github.com/rest/commits/commits#get-a-commit",
#   "status": "422"
# }
#
# Output written to repo_baby_pr_event_merge_commit_commit_None.patch
#
#
# head: https://github.com/2dot71mily/repo_baby/commit/f2af16a103f445845fc59ca5ad126789f1356cde
# From f2af16a103f445845fc59ca5ad126789f1356cde Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 21:17:39 -0700
# Subject: [PATCH] add workflow
#
# ---
#  .github/workflows/python-app.yml | 39 ++++++++++++++++++++++++++++++++
#  1 file changed, 39 insertions(+)
#  create mode 100644 .github/workflows/python-app.yml
#
# diff --git a/.github/workflows/python-app.yml b/.github/wo
# <truncated>
#
# Output written to repo_baby_pr_event_head_commit_f2af16a103f445845fc59ca5ad126789f1356cde.patch
#
#
# base: https://github.com/2dot71mily/repo_baby/commit/d82a833b896ee0bb684db799a8d06e4320b3586e
# From d82a833b896ee0bb684db799a8d06e4320b3586e Mon Sep 17 00:00:00 2001
# From: Emily McMilin <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:44:46 -0700
# Subject: [PATCH] mod readme (#6)
#
# ---
#  README.md | 9 +++++++++
#  1 file changed, 9 insertions(+)
#
# diff --git a/README.md b/README.md
# index 8bc8734..b608cb0 100644
# --- a/README.md
# +++ b/README.md
# @@ -1 +1,10 @@
#  # repo_baby
# +
# +This main dir is fun
# <truncated>
#
# Output written to repo_baby_pr_event_base_commit_d82a833b896ee0bb684db799a8d06e4320b3586e.patch
#
#
#  ******** PR6 pr_event iter 8 ********
# merge_commit: https://github.com/2dot71mily/repo_baby/commit/d82a833b896ee0bb684db799a8d06e4320b3586e
# From d82a833b896ee0bb684db799a8d06e4320b3586e Mon Sep 17 00:00:00 2001
# From: Emily McMilin <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:44:46 -0700
# Subject: [PATCH] mod readme (#6)
#
# ---
#  README.md | 9 +++++++++
#  1 file changed, 9 insertions(+)
#
# diff --git a/README.md b/README.md
# index 8bc8734..b608cb0 100644
# --- a/README.md
# +++ b/README.md
# @@ -1 +1,10 @@
#  # repo_baby
# +
# +This main dir is fun
# <truncated>
#
# Output written to repo_baby_pr_event_merge_commit_commit_d82a833b896ee0bb684db799a8d06e4320b3586e.patch
#
#
# head: https://github.com/2dot71mily/repo_baby/commit/8a9060cd91184699b05dbccde30f66a3aa51beae
# From 8a9060cd91184699b05dbccde30f66a3aa51beae Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:43:09 -0700
# Subject: [PATCH] mod readme
#
# ---
#  README.md | 9 +++++++++
#  1 file changed, 9 insertions(+)
#
# diff --git a/README.md b/README.md
# index 8bc8734..b608cb0 100644
# --- a/README.md
# +++ b/README.md
# @@ -1 +1,10 @@
#  # repo_baby
# +
# +This main dir is function & unitt
# <truncated>
#
# Output written to repo_baby_pr_event_head_commit_8a9060cd91184699b05dbccde30f66a3aa51beae.patch
#
#
# base: https://github.com/2dot71mily/repo_baby/commit/9dc1da5f2540fac8eaf1adc3f8ee909d65e7bba9
# From 9dc1da5f2540fac8eaf1adc3f8ee909d65e7bba9 Mon Sep 17 00:00:00 2001
# From: Emily McMilin <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:40:21 -0700
# Subject: [PATCH] Gh data (#5)
#
# * add gh event data
#
# * add gh pr commits data
#
# * add gh readme
# ---
#  gh_data/README.md                  |   25 +
#  gh_data/repo_baby_events.json      | 3454 ++++++++++++++++++++++++++++
#  gh_data/repo_baby_pr4_commits
# <truncated>
#
# Output written to repo_baby_pr_event_base_commit_9dc1da5f2540fac8eaf1adc3f8ee909d65e7bba9.patch
#
#
#  ******** PR6 pr_event iter 9 ********
# merge_commit: https://github.com/2dot71mily/repo_baby/commit/None
# {
#   "message": "No commit found for SHA: None",
#   "documentation_url": "https://docs.github.com/rest/commits/commits#get-a-commit",
#   "status": "422"
# }
#
# Output written to repo_baby_pr_event_merge_commit_commit_None.patch
#
#
# head: https://github.com/2dot71mily/repo_baby/commit/8a9060cd91184699b05dbccde30f66a3aa51beae
# From 8a9060cd91184699b05dbccde30f66a3aa51beae Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:43:09 -0700
# Subject: [PATCH] mod readme
#
# ---
#  README.md | 9 +++++++++
#  1 file changed, 9 insertions(+)
#
# diff --git a/README.md b/README.md
# index 8bc8734..b608cb0 100644
# --- a/README.md
# +++ b/README.md
# @@ -1 +1,10 @@
#  # repo_baby
# +
# +This main dir is function & unitt
# <truncated>
#
# Output written to repo_baby_pr_event_head_commit_8a9060cd91184699b05dbccde30f66a3aa51beae.patch
#
#
# base: https://github.com/2dot71mily/repo_baby/commit/9dc1da5f2540fac8eaf1adc3f8ee909d65e7bba9
# From 9dc1da5f2540fac8eaf1adc3f8ee909d65e7bba9 Mon Sep 17 00:00:00 2001
# From: Emily McMilin <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:40:21 -0700
# Subject: [PATCH] Gh data (#5)
#
# * add gh event data
#
# * add gh pr commits data
#
# * add gh readme
# ---
#  gh_data/README.md                  |   25 +
#  gh_data/repo_baby_events.json      | 3454 ++++++++++++++++++++++++++++
#  gh_data/repo_baby_pr4_commits
# <truncated>
#
# Output written to repo_baby_pr_event_base_commit_9dc1da5f2540fac8eaf1adc3f8ee909d65e7bba9.patch
#
#
#  ******** PR5 pr_event iter 12 ********
# merge_commit: https://github.com/2dot71mily/repo_baby/commit/9dc1da5f2540fac8eaf1adc3f8ee909d65e7bba9
# From 9dc1da5f2540fac8eaf1adc3f8ee909d65e7bba9 Mon Sep 17 00:00:00 2001
# From: Emily McMilin <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:40:21 -0700
# Subject: [PATCH] Gh data (#5)
#
# * add gh event data
#
# * add gh pr commits data
#
# * add gh readme
# ---
#  gh_data/README.md                  |   25 +
#  gh_data/repo_baby_events.json      | 3454 ++++++++++++++++++++++++++++
#  gh_data/repo_baby_pr4_commits
# <truncated>
#
# Output written to repo_baby_pr_event_merge_commit_commit_9dc1da5f2540fac8eaf1adc3f8ee909d65e7bba9.patch
#
#
# head: https://github.com/2dot71mily/repo_baby/commit/de097b254ae98da990f0d1617446ce595f041f22
# From de097b254ae98da990f0d1617446ce595f041f22 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:39:31 -0700
# Subject: [PATCH] add gh readme
#
# ---
#  gh_data/README.md | 25 +++++++++++++++++++++++++
#  1 file changed, 25 insertions(+)
#  create mode 100644 gh_data/README.md
#
# diff --git a/gh_data/README.md b/gh_data/README.md
# new file mode 100644
# index 0000000..c538337
# <truncated>
#
# Output written to repo_baby_pr_event_head_commit_de097b254ae98da990f0d1617446ce595f041f22.patch
#
#
# base: https://github.com/2dot71mily/repo_baby/commit/54f74499904759cc7f01217be44f271b00660b5c
# From 54f74499904759cc7f01217be44f271b00660b5c Mon Sep 17 00:00:00 2001
# From: Emily McMilin <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:24:21 -0700
# Subject: [PATCH] Docker (#4)
#
# * add docker file
#
# * add docker compose
#
# * add docker readme
#
# * mod gitignore
# ---
#  .gitignore                 |  1 +
#  docker/README.md           | 39 ++++++++++++++++++++++++++++++++++++++
#  docker/docker-compose.yam
# <truncated>
#
# Output written to repo_baby_pr_event_base_commit_54f74499904759cc7f01217be44f271b00660b5c.patch
#
#
#  ******** PR5 pr_event iter 13 ********
# merge_commit: https://github.com/2dot71mily/repo_baby/commit/None
# {
#   "message": "No commit found for SHA: None",
#   "documentation_url": "https://docs.github.com/rest/commits/commits#get-a-commit",
#   "status": "422"
# }
#
# Output written to repo_baby_pr_event_merge_commit_commit_None.patch
#
#
# head: https://github.com/2dot71mily/repo_baby/commit/de097b254ae98da990f0d1617446ce595f041f22
# From de097b254ae98da990f0d1617446ce595f041f22 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:39:31 -0700
# Subject: [PATCH] add gh readme
#
# ---
#  gh_data/README.md | 25 +++++++++++++++++++++++++
#  1 file changed, 25 insertions(+)
#  create mode 100644 gh_data/README.md
#
# diff --git a/gh_data/README.md b/gh_data/README.md
# new file mode 100644
# index 0000000..c538337
# <truncated>
#
# Output written to repo_baby_pr_event_head_commit_de097b254ae98da990f0d1617446ce595f041f22.patch
#
#
# base: https://github.com/2dot71mily/repo_baby/commit/54f74499904759cc7f01217be44f271b00660b5c
# From 54f74499904759cc7f01217be44f271b00660b5c Mon Sep 17 00:00:00 2001
# From: Emily McMilin <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:24:21 -0700
# Subject: [PATCH] Docker (#4)
#
# * add docker file
#
# * add docker compose
#
# * add docker readme
#
# * mod gitignore
# ---
#  .gitignore                 |  1 +
#  docker/README.md           | 39 ++++++++++++++++++++++++++++++++++++++
#  docker/docker-compose.yam
# <truncated>
#
# Output written to repo_baby_pr_event_base_commit_54f74499904759cc7f01217be44f271b00660b5c.patch
#
#
#  ******** PR4 pr_event iter 16 ********
# merge_commit: https://github.com/2dot71mily/repo_baby/commit/54f74499904759cc7f01217be44f271b00660b5c
# From 54f74499904759cc7f01217be44f271b00660b5c Mon Sep 17 00:00:00 2001
# From: Emily McMilin <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:24:21 -0700
# Subject: [PATCH] Docker (#4)
#
# * add docker file
#
# * add docker compose
#
# * add docker readme
#
# * mod gitignore
# ---
#  .gitignore                 |  1 +
#  docker/README.md           | 39 ++++++++++++++++++++++++++++++++++++++
#  docker/docker-compose.yam
# <truncated>
#
# Output written to repo_baby_pr_event_merge_commit_commit_54f74499904759cc7f01217be44f271b00660b5c.patch
#
#
# head: https://github.com/2dot71mily/repo_baby/commit/c86315ccfa145f10638c6c976d1a440cf4226ad5
# From c86315ccfa145f10638c6c976d1a440cf4226ad5 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:23:32 -0700
# Subject: [PATCH] mod gitignore
#
# ---
#  .gitignore | 1 +
#  1 file changed, 1 insertion(+)
#
# diff --git a/.gitignore b/.gitignore
# index 691037e..26be7c1 100644
# --- a/.gitignore
# +++ b/.gitignore
# @@ -1 +1,2 @@
#  .venv/*
# +.DS_Store
#
# Output written to repo_baby_pr_event_head_commit_c86315ccfa145f10638c6c976d1a440cf4226ad5.patch
#
#
# base: https://github.com/2dot71mily/repo_baby/commit/65011a595213edd701bae8396cf477e0934ae676
# From 73af5f6f8b1ebe50606260b11c7cedd9d65f1b04 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:18:07 -0700
# Subject: [PATCH 1/2] add strings
#
# ---
#  string_operations.py | 10 ++++++++++
#  1 file changed, 10 insertions(+)
#  create mode 100644 string_operations.py
#
# diff --git a/string_operations.py b/string_operations.py
# new file mode 100644
# index 0000000..2c42911
#
# <truncated>
#
# Output written to repo_baby_pr_event_base_commit_65011a595213edd701bae8396cf477e0934ae676.patch
#
#
#  ******** PR4 pr_event iter 17 ********
# merge_commit: https://github.com/2dot71mily/repo_baby/commit/None
# {
#   "message": "No commit found for SHA: None",
#   "documentation_url": "https://docs.github.com/rest/commits/commits#get-a-commit",
#   "status": "422"
# }
#
# Output written to repo_baby_pr_event_merge_commit_commit_None.patch
#
#
# head: https://github.com/2dot71mily/repo_baby/commit/c86315ccfa145f10638c6c976d1a440cf4226ad5
# From c86315ccfa145f10638c6c976d1a440cf4226ad5 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:23:32 -0700
# Subject: [PATCH] mod gitignore
#
# ---
#  .gitignore | 1 +
#  1 file changed, 1 insertion(+)
#
# diff --git a/.gitignore b/.gitignore
# index 691037e..26be7c1 100644
# --- a/.gitignore
# +++ b/.gitignore
# @@ -1 +1,2 @@
#  .venv/*
# +.DS_Store
#
# Output written to repo_baby_pr_event_head_commit_c86315ccfa145f10638c6c976d1a440cf4226ad5.patch
#
#
# base: https://github.com/2dot71mily/repo_baby/commit/65011a595213edd701bae8396cf477e0934ae676
# From 73af5f6f8b1ebe50606260b11c7cedd9d65f1b04 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:18:07 -0700
# Subject: [PATCH 1/2] add strings
#
# ---
#  string_operations.py | 10 ++++++++++
#  1 file changed, 10 insertions(+)
#  create mode 100644 string_operations.py
#
# diff --git a/string_operations.py b/string_operations.py
# new file mode 100644
# index 0000000..2c42911
#
# <truncated>
#
# Output written to repo_baby_pr_event_base_commit_65011a595213edd701bae8396cf477e0934ae676.patch
#
#
#  ******** PR3 pr_event iter 20 ********
# merge_commit: https://github.com/2dot71mily/repo_baby/commit/65011a595213edd701bae8396cf477e0934ae676
# From 73af5f6f8b1ebe50606260b11c7cedd9d65f1b04 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:18:07 -0700
# Subject: [PATCH 1/2] add strings
#
# ---
#  string_operations.py | 10 ++++++++++
#  1 file changed, 10 insertions(+)
#  create mode 100644 string_operations.py
#
# diff --git a/string_operations.py b/string_operations.py
# new file mode 100644
# index 0000000..2c42911
#
# <truncated>
#
# Output written to repo_baby_pr_event_merge_commit_commit_65011a595213edd701bae8396cf477e0934ae676.patch
#
#
# head: https://github.com/2dot71mily/repo_baby/commit/fe9ef9c93f7415d790def19e43090bb213e3db44
# From fe9ef9c93f7415d790def19e43090bb213e3db44 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:18:18 -0700
# Subject: [PATCH] add strings tests
#
# ---
#  test_string_operations.py | 22 ++++++++++++++++++++++
#  1 file changed, 22 insertions(+)
#  create mode 100644 test_string_operations.py
#
# diff --git a/test_string_operations.py b/test_string_operations.py
# new file m
# <truncated>
#
# Output written to repo_baby_pr_event_head_commit_fe9ef9c93f7415d790def19e43090bb213e3db44.patch
#
#
# base: https://github.com/2dot71mily/repo_baby/commit/9d99f14d46394306ede6cf2207928fbe1ce20c7b
# From 9d99f14d46394306ede6cf2207928fbe1ce20c7b Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:15:39 -0700
# Subject: [PATCH] add requirements
#
# ---
#  requirements.txt | 1 +
#  1 file changed, 1 insertion(+)
#  create mode 100644 requirements.txt
#
# diff --git a/requirements.txt b/requirements.txt
# new file mode 100644
# index 0000000..2cf9b04
# --- /dev/null
# +++ b/require
# <truncated>
#
# Output written to repo_baby_pr_event_base_commit_9d99f14d46394306ede6cf2207928fbe1ce20c7b.patch
#
#
#  ******** PR3 pr_event iter 21 ********
# merge_commit: https://github.com/2dot71mily/repo_baby/commit/None
# {
#   "message": "No commit found for SHA: None",
#   "documentation_url": "https://docs.github.com/rest/commits/commits#get-a-commit",
#   "status": "422"
# }
#
# Output written to repo_baby_pr_event_merge_commit_commit_None.patch
#
#
# head: https://github.com/2dot71mily/repo_baby/commit/fe9ef9c93f7415d790def19e43090bb213e3db44
# From fe9ef9c93f7415d790def19e43090bb213e3db44 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:18:18 -0700
# Subject: [PATCH] add strings tests
#
# ---
#  test_string_operations.py | 22 ++++++++++++++++++++++
#  1 file changed, 22 insertions(+)
#  create mode 100644 test_string_operations.py
#
# diff --git a/test_string_operations.py b/test_string_operations.py
# new file m
# <truncated>
#
# Output written to repo_baby_pr_event_head_commit_fe9ef9c93f7415d790def19e43090bb213e3db44.patch
#
#
# base: https://github.com/2dot71mily/repo_baby/commit/9d99f14d46394306ede6cf2207928fbe1ce20c7b
# From 9d99f14d46394306ede6cf2207928fbe1ce20c7b Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:15:39 -0700
# Subject: [PATCH] add requirements
#
# ---
#  requirements.txt | 1 +
#  1 file changed, 1 insertion(+)
#  create mode 100644 requirements.txt
#
# diff --git a/requirements.txt b/requirements.txt
# new file mode 100644
# index 0000000..2cf9b04
# --- /dev/null
# +++ b/require
# <truncated>
#
# Output written to repo_baby_pr_event_base_commit_9d99f14d46394306ede6cf2207928fbe1ce20c7b.patch
#
#
#  ******** PR2 pr_event iter 25 ********
# merge_commit: https://github.com/2dot71mily/repo_baby/commit/9ba3b0c014c30ff2b60fc5d6097a231e8cf4cb6d
# From 9ba3b0c014c30ff2b60fc5d6097a231e8cf4cb6d Mon Sep 17 00:00:00 2001
# From: Emily McMilin <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:11:46 -0700
# Subject: [PATCH] List (#2)
#
# * add list
#
# * add list tests
# ---
#  list_operations.py      | 10 ++++++++++
#  test_list_operations.py | 25 +++++++++++++++++++++++++
#  2 files changed, 35 insertions(+)
#  create mode 100644 list_operations.py
#  create mode
# <truncated>
#
# Output written to repo_baby_pr_event_merge_commit_commit_9ba3b0c014c30ff2b60fc5d6097a231e8cf4cb6d.patch
#
#
# head: https://github.com/2dot71mily/repo_baby/commit/9d7f978e7ea315308da8fe2dccf2cf2568a240e2
# From 9d7f978e7ea315308da8fe2dccf2cf2568a240e2 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:10:58 -0700
# Subject: [PATCH] add list tests
#
# ---
#  test_list_operations.py | 25 +++++++++++++++++++++++++
#  1 file changed, 25 insertions(+)
#  create mode 100644 test_list_operations.py
#
# diff --git a/test_list_operations.py b/test_list_operations.py
# new file mode 1006
# <truncated>
#
# Output written to repo_baby_pr_event_head_commit_9d7f978e7ea315308da8fe2dccf2cf2568a240e2.patch
#
#
# base: https://github.com/2dot71mily/repo_baby/commit/49ed8647345e38270e6362fbb895abc27d7849f9
# From c301e5404dcbd7a693473f9579b12b968c622853 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:08:16 -0700
# Subject: [PATCH 1/2] add math
#
# ---
#  math_operations.py | 13 +++++++++++++
#  1 file changed, 13 insertions(+)
#  create mode 100644 math_operations.py
#
# diff --git a/math_operations.py b/math_operations.py
# new file mode 100644
# index 0000000..f7f69b3
# --- /dev
# <truncated>
#
# Output written to repo_baby_pr_event_base_commit_49ed8647345e38270e6362fbb895abc27d7849f9.patch
#
#
#  ******** PR2 pr_event iter 26 ********
# merge_commit: https://github.com/2dot71mily/repo_baby/commit/None
# {
#   "message": "No commit found for SHA: None",
#   "documentation_url": "https://docs.github.com/rest/commits/commits#get-a-commit",
#   "status": "422"
# }
#
# Output written to repo_baby_pr_event_merge_commit_commit_None.patch
#
#
# head: https://github.com/2dot71mily/repo_baby/commit/9d7f978e7ea315308da8fe2dccf2cf2568a240e2
# From 9d7f978e7ea315308da8fe2dccf2cf2568a240e2 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:10:58 -0700
# Subject: [PATCH] add list tests
#
# ---
#  test_list_operations.py | 25 +++++++++++++++++++++++++
#  1 file changed, 25 insertions(+)
#  create mode 100644 test_list_operations.py
#
# diff --git a/test_list_operations.py b/test_list_operations.py
# new file mode 1006
# <truncated>
#
# Output written to repo_baby_pr_event_head_commit_9d7f978e7ea315308da8fe2dccf2cf2568a240e2.patch
#
#
# base: https://github.com/2dot71mily/repo_baby/commit/49ed8647345e38270e6362fbb895abc27d7849f9
# From c301e5404dcbd7a693473f9579b12b968c622853 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:08:16 -0700
# Subject: [PATCH 1/2] add math
#
# ---
#  math_operations.py | 13 +++++++++++++
#  1 file changed, 13 insertions(+)
#  create mode 100644 math_operations.py
#
# diff --git a/math_operations.py b/math_operations.py
# new file mode 100644
# index 0000000..f7f69b3
# --- /dev
# <truncated>
#
# Output written to repo_baby_pr_event_base_commit_49ed8647345e38270e6362fbb895abc27d7849f9.patch
#
#
#  ******** PR1 pr_event iter 29 ********
# merge_commit: https://github.com/2dot71mily/repo_baby/commit/49ed8647345e38270e6362fbb895abc27d7849f9
# From c301e5404dcbd7a693473f9579b12b968c622853 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:08:16 -0700
# Subject: [PATCH 1/2] add math
#
# ---
#  math_operations.py | 13 +++++++++++++
#  1 file changed, 13 insertions(+)
#  create mode 100644 math_operations.py
#
# diff --git a/math_operations.py b/math_operations.py
# new file mode 100644
# index 0000000..f7f69b3
# --- /dev
# <truncated>
#
# Output written to repo_baby_pr_event_merge_commit_commit_49ed8647345e38270e6362fbb895abc27d7849f9.patch
#
#
# head: https://github.com/2dot71mily/repo_baby/commit/95c67239fa5cb1c47013d2ade665914c947f9d78
# From 95c67239fa5cb1c47013d2ade665914c947f9d78 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:08:25 -0700
# Subject: [PATCH] add math tests
#
# ---
#  test_math_operations.py | 30 ++++++++++++++++++++++++++++++
#  1 file changed, 30 insertions(+)
#  create mode 100644 test_math_operations.py
#
# diff --git a/test_math_operations.py b/test_math_operations.py
# new file mode
# <truncated>
#
# Output written to repo_baby_pr_event_head_commit_95c67239fa5cb1c47013d2ade665914c947f9d78.patch
#
#
# base: https://github.com/2dot71mily/repo_baby/commit/26ddf36ea221b2856901d8f7f26b07872e1276c4
# From 26ddf36ea221b2856901d8f7f26b07872e1276c4 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:06:58 -0700
# Subject: [PATCH] setup
#
# ---
#  .gitignore | 1 +
#  1 file changed, 1 insertion(+)
#  create mode 100644 .gitignore
#
# diff --git a/.gitignore b/.gitignore
# new file mode 100644
# index 0000000..691037e
# --- /dev/null
# +++ b/.gitignore
# @@ -0,0 +1 @@
# +.venv/*
#
# Output written to repo_baby_pr_event_base_commit_26ddf36ea221b2856901d8f7f26b07872e1276c4.patch
#
#
#  ******** PR1 pr_event iter 30 ********
# merge_commit: https://github.com/2dot71mily/repo_baby/commit/None
# {
#   "message": "No commit found for SHA: None",
#   "documentation_url": "https://docs.github.com/rest/commits/commits#get-a-commit",
#   "status": "422"
# }
#
# Output written to repo_baby_pr_event_merge_commit_commit_None.patch
#
#
# head: https://github.com/2dot71mily/repo_baby/commit/95c67239fa5cb1c47013d2ade665914c947f9d78
# From 95c67239fa5cb1c47013d2ade665914c947f9d78 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:08:25 -0700
# Subject: [PATCH] add math tests
#
# ---
#  test_math_operations.py | 30 ++++++++++++++++++++++++++++++
#  1 file changed, 30 insertions(+)
#  create mode 100644 test_math_operations.py
#
# diff --git a/test_math_operations.py b/test_math_operations.py
# new file mode
# <truncated>
#
# Output written to repo_baby_pr_event_head_commit_95c67239fa5cb1c47013d2ade665914c947f9d78.patch
#
#
# base: https://github.com/2dot71mily/repo_baby/commit/26ddf36ea221b2856901d8f7f26b07872e1276c4
# From 26ddf36ea221b2856901d8f7f26b07872e1276c4 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:06:58 -0700
# Subject: [PATCH] setup
#
# ---
#  .gitignore | 1 +
#  1 file changed, 1 insertion(+)
#  create mode 100644 .gitignore
#
# diff --git a/.gitignore b/.gitignore
# new file mode 100644
# index 0000000..691037e
# --- /dev/null
# +++ b/.gitignore
# @@ -0,0 +1 @@
# +.venv/*
#
# Output written to repo_baby_pr_event_base_commit_26ddf36ea221b2856901d8f7f26b07872e1276c4.patch

# %% [markdown]
# ## Checking PushEvents as well

# %%
for i, push_event in data_by_type["PushEvent"].iterrows():
    print(f" ******** PushEvent iter {i} ******** ")
    for j, commit in enumerate(push_event.payload["commits"]):
        sha = commit["sha"]
        print(f"commit {j}: {html_commit_template.format(sha=sha)}")
        try:
            get_cleaned_gh_cmd_output(
                commits_cmd_template.format(sha=sha),
                output_filename=commit_output_filename_template.format(
                    prefix=f"push_event_{i}_commit_{j}", sha=sha
                ),
                api_cmd_template=api_cmd_patch_template,
                verbose=True,
            )
        except Exception as e:
            print(f"Failed to retrieve data for sha: {sha}")
            print(e)
            continue
# Out:
#  ******** PushEvent iter 0 ********
# commit 0: https://github.com/2dot71mily/repo_baby/commit/e8e3e3560a80eecc68ab5439fc67d82030ba0083
# From e8e3e3560a80eecc68ab5439fc67d82030ba0083 Mon Sep 17 00:00:00 2001
# From: Emily McMilin <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 21:33:06 -0700
# Subject: [PATCH] add workflow (#7)
#
# * add workflow
#
# * add logistic regression
#
# * add test logistic regression
#
# * add e2e
#
# * add e2e test
# ---
#  .github/workflows/python-app.yml | 39 +++++++++++++++++++++++++++
#  e2e_logistic_regression.py       | 4
# <truncated>
#
# Output written to repo_baby_push_event_0_commit_0_e8e3e3560a80eecc68ab5439fc67d82030ba0083.patch
#
#
#  ******** PushEvent iter 2 ********
# commit 0: https://github.com/2dot71mily/repo_baby/commit/5dc0480ed997d2bfeb40e79de900e71e097632b4
# From 5dc0480ed997d2bfeb40e79de900e71e097632b4 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 21:31:01 -0700
# Subject: [PATCH] add e2e
#
# ---
#  e2e_logistic_regression.py | 46 ++++++++++++++++++++++++++++++++++++++
#  1 file changed, 46 insertions(+)
#  create mode 100644 e2e_logistic_regression.py
#
# diff --git a/e2e_logistic_regression.py b/e2e_logistic_regression.py
#
# <truncated>
#
# Output written to repo_baby_push_event_2_commit_0_5dc0480ed997d2bfeb40e79de900e71e097632b4.patch
#
#
# commit 1: https://github.com/2dot71mily/repo_baby/commit/58f63591312000428772626e100c6c801d0d4ea0
# From 58f63591312000428772626e100c6c801d0d4ea0 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 21:31:11 -0700
# Subject: [PATCH] add e2e test
#
# ---
#  test_e2e_logistic_regression.py | 6 ++++++
#  1 file changed, 6 insertions(+)
#  create mode 100644 test_e2e_logistic_regression.py
#
# diff --git a/test_e2e_logistic_regression.py b/test_e2e_logistic_regression.py
# new file
# <truncated>
#
# Output written to repo_baby_push_event_2_commit_1_58f63591312000428772626e100c6c801d0d4ea0.patch
#
#
#  ******** PushEvent iter 3 ********
# commit 0: https://github.com/2dot71mily/repo_baby/commit/3f559e1ec3cfb480b039e95867c552b9f7a10627
# From 3f559e1ec3cfb480b039e95867c552b9f7a10627 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 21:22:23 -0700
# Subject: [PATCH] add logistic regression
#
# ---
#  logistic_regression.py | 34 ++++++++++++++++++++++++++++++++++
#  1 file changed, 34 insertions(+)
#  create mode 100644 logistic_regression.py
#
# diff --git a/logistic_regression.py b/logistic_regression.py
# new
# <truncated>
#
# Output written to repo_baby_push_event_3_commit_0_3f559e1ec3cfb480b039e95867c552b9f7a10627.patch
#
#
# commit 1: https://github.com/2dot71mily/repo_baby/commit/a81a26b8c4308e476ebbeaeded202b86e7fe9877
# From a81a26b8c4308e476ebbeaeded202b86e7fe9877 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 21:22:36 -0700
# Subject: [PATCH] add test logistic regression
#
# ---
#  test_logistic_regression.py | 33 +++++++++++++++++++++++++++++++++
#  1 file changed, 33 insertions(+)
#  create mode 100644 test_logistic_regression.py
#
# diff --git a/test_logistic_regression.py b/test_log
# <truncated>
#
# Output written to repo_baby_push_event_3_commit_1_a81a26b8c4308e476ebbeaeded202b86e7fe9877.patch
#
#
#  ******** PushEvent iter 7 ********
# commit 0: https://github.com/2dot71mily/repo_baby/commit/d82a833b896ee0bb684db799a8d06e4320b3586e
# From d82a833b896ee0bb684db799a8d06e4320b3586e Mon Sep 17 00:00:00 2001
# From: Emily McMilin <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:44:46 -0700
# Subject: [PATCH] mod readme (#6)
#
# ---
#  README.md | 9 +++++++++
#  1 file changed, 9 insertions(+)
#
# diff --git a/README.md b/README.md
# index 8bc8734..b608cb0 100644
# --- a/README.md
# +++ b/README.md
# @@ -1 +1,10 @@
#  # repo_baby
# +
# +This main dir is fun
# <truncated>
#
# Output written to repo_baby_push_event_7_commit_0_d82a833b896ee0bb684db799a8d06e4320b3586e.patch
#
#
#  ******** PushEvent iter 11 ********
# commit 0: https://github.com/2dot71mily/repo_baby/commit/9dc1da5f2540fac8eaf1adc3f8ee909d65e7bba9
# From 9dc1da5f2540fac8eaf1adc3f8ee909d65e7bba9 Mon Sep 17 00:00:00 2001
# From: Emily McMilin <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:40:21 -0700
# Subject: [PATCH] Gh data (#5)
#
# * add gh event data
#
# * add gh pr commits data
#
# * add gh readme
# ---
#  gh_data/README.md                  |   25 +
#  gh_data/repo_baby_events.json      | 3454 ++++++++++++++++++++++++++++
#  gh_data/repo_baby_pr4_commits
# <truncated>
#
# Output written to repo_baby_push_event_11_commit_0_9dc1da5f2540fac8eaf1adc3f8ee909d65e7bba9.patch
#
#
#  ******** PushEvent iter 15 ********
# commit 0: https://github.com/2dot71mily/repo_baby/commit/54f74499904759cc7f01217be44f271b00660b5c
# From 54f74499904759cc7f01217be44f271b00660b5c Mon Sep 17 00:00:00 2001
# From: Emily McMilin <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:24:21 -0700
# Subject: [PATCH] Docker (#4)
#
# * add docker file
#
# * add docker compose
#
# * add docker readme
#
# * mod gitignore
# ---
#  .gitignore                 |  1 +
#  docker/README.md           | 39 ++++++++++++++++++++++++++++++++++++++
#  docker/docker-compose.yam
# <truncated>
#
# Output written to repo_baby_push_event_15_commit_0_54f74499904759cc7f01217be44f271b00660b5c.patch
#
#
#  ******** PushEvent iter 19 ********
# commit 0: https://github.com/2dot71mily/repo_baby/commit/73af5f6f8b1ebe50606260b11c7cedd9d65f1b04
# From 73af5f6f8b1ebe50606260b11c7cedd9d65f1b04 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:18:07 -0700
# Subject: [PATCH] add strings
#
# ---
#  string_operations.py | 10 ++++++++++
#  1 file changed, 10 insertions(+)
#  create mode 100644 string_operations.py
#
# diff --git a/string_operations.py b/string_operations.py
# new file mode 100644
# index 0000000..2c42911
# ---
# <truncated>
#
# Output written to repo_baby_push_event_19_commit_0_73af5f6f8b1ebe50606260b11c7cedd9d65f1b04.patch
#
#
# commit 1: https://github.com/2dot71mily/repo_baby/commit/fe9ef9c93f7415d790def19e43090bb213e3db44
# From fe9ef9c93f7415d790def19e43090bb213e3db44 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:18:18 -0700
# Subject: [PATCH] add strings tests
#
# ---
#  test_string_operations.py | 22 ++++++++++++++++++++++
#  1 file changed, 22 insertions(+)
#  create mode 100644 test_string_operations.py
#
# diff --git a/test_string_operations.py b/test_string_operations.py
# new file m
# <truncated>
#
# Output written to repo_baby_push_event_19_commit_1_fe9ef9c93f7415d790def19e43090bb213e3db44.patch
#
#
# commit 2: https://github.com/2dot71mily/repo_baby/commit/65011a595213edd701bae8396cf477e0934ae676
# From 73af5f6f8b1ebe50606260b11c7cedd9d65f1b04 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:18:07 -0700
# Subject: [PATCH 1/2] add strings
#
# ---
#  string_operations.py | 10 ++++++++++
#  1 file changed, 10 insertions(+)
#  create mode 100644 string_operations.py
#
# diff --git a/string_operations.py b/string_operations.py
# new file mode 100644
# index 0000000..2c42911
#
# <truncated>
#
# Output written to repo_baby_push_event_19_commit_2_65011a595213edd701bae8396cf477e0934ae676.patch
#
#
#  ******** PushEvent iter 23 ********
# commit 0: https://github.com/2dot71mily/repo_baby/commit/490e69d8aa180680d8457d93c2a7ed63c903cb80
# From 490e69d8aa180680d8457d93c2a7ed63c903cb80 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:15:15 -0700
# Subject: [PATCH] add array
#
# ---
#  array_operations.py | 19 +++++++++++++++++++
#  1 file changed, 19 insertions(+)
#  create mode 100644 array_operations.py
#
# diff --git a/array_operations.py b/array_operations.py
# new file mode 100644
# index 0000000..ef079c4
# -
# <truncated>
#
# Output written to repo_baby_push_event_23_commit_0_490e69d8aa180680d8457d93c2a7ed63c903cb80.patch
#
#
# commit 1: https://github.com/2dot71mily/repo_baby/commit/c142fd5e8f477ab09d772f6cf52f83427313a74a
# From c142fd5e8f477ab09d772f6cf52f83427313a74a Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:15:26 -0700
# Subject: [PATCH] add array tests
#
# ---
#  test_array_operations.py | 36 ++++++++++++++++++++++++++++++++++++
#  1 file changed, 36 insertions(+)
#  create mode 100644 test_array_operations.py
#
# diff --git a/test_array_operations.py b/test_array_operations.py
# ne
# <truncated>
#
# Output written to repo_baby_push_event_23_commit_1_c142fd5e8f477ab09d772f6cf52f83427313a74a.patch
#
#
# commit 2: https://github.com/2dot71mily/repo_baby/commit/9d99f14d46394306ede6cf2207928fbe1ce20c7b
# From 9d99f14d46394306ede6cf2207928fbe1ce20c7b Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:15:39 -0700
# Subject: [PATCH] add requirements
#
# ---
#  requirements.txt | 1 +
#  1 file changed, 1 insertion(+)
#  create mode 100644 requirements.txt
#
# diff --git a/requirements.txt b/requirements.txt
# new file mode 100644
# index 0000000..2cf9b04
# --- /dev/null
# +++ b/require
# <truncated>
#
# Output written to repo_baby_push_event_23_commit_2_9d99f14d46394306ede6cf2207928fbe1ce20c7b.patch
#
#
#  ******** PushEvent iter 24 ********
# commit 0: https://github.com/2dot71mily/repo_baby/commit/9ba3b0c014c30ff2b60fc5d6097a231e8cf4cb6d
# From 9ba3b0c014c30ff2b60fc5d6097a231e8cf4cb6d Mon Sep 17 00:00:00 2001
# From: Emily McMilin <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:11:46 -0700
# Subject: [PATCH] List (#2)
#
# * add list
#
# * add list tests
# ---
#  list_operations.py      | 10 ++++++++++
#  test_list_operations.py | 25 +++++++++++++++++++++++++
#  2 files changed, 35 insertions(+)
#  create mode 100644 list_operations.py
#  create mode
# <truncated>
#
# Output written to repo_baby_push_event_24_commit_0_9ba3b0c014c30ff2b60fc5d6097a231e8cf4cb6d.patch
#
#
#  ******** PushEvent iter 28 ********
# commit 0: https://github.com/2dot71mily/repo_baby/commit/c301e5404dcbd7a693473f9579b12b968c622853
# From c301e5404dcbd7a693473f9579b12b968c622853 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:08:16 -0700
# Subject: [PATCH] add math
#
# ---
#  math_operations.py | 13 +++++++++++++
#  1 file changed, 13 insertions(+)
#  create mode 100644 math_operations.py
#
# diff --git a/math_operations.py b/math_operations.py
# new file mode 100644
# index 0000000..f7f69b3
# --- /dev/nul
# <truncated>
#
# Output written to repo_baby_push_event_28_commit_0_c301e5404dcbd7a693473f9579b12b968c622853.patch
#
#
# commit 1: https://github.com/2dot71mily/repo_baby/commit/95c67239fa5cb1c47013d2ade665914c947f9d78
# From 95c67239fa5cb1c47013d2ade665914c947f9d78 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:08:25 -0700
# Subject: [PATCH] add math tests
#
# ---
#  test_math_operations.py | 30 ++++++++++++++++++++++++++++++
#  1 file changed, 30 insertions(+)
#  create mode 100644 test_math_operations.py
#
# diff --git a/test_math_operations.py b/test_math_operations.py
# new file mode
# <truncated>
#
# Output written to repo_baby_push_event_28_commit_1_95c67239fa5cb1c47013d2ade665914c947f9d78.patch
#
#
# commit 2: https://github.com/2dot71mily/repo_baby/commit/49ed8647345e38270e6362fbb895abc27d7849f9
# From c301e5404dcbd7a693473f9579b12b968c622853 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:08:16 -0700
# Subject: [PATCH 1/2] add math
#
# ---
#  math_operations.py | 13 +++++++++++++
#  1 file changed, 13 insertions(+)
#  create mode 100644 math_operations.py
#
# diff --git a/math_operations.py b/math_operations.py
# new file mode 100644
# index 0000000..f7f69b3
# --- /dev
# <truncated>
#
# Output written to repo_baby_push_event_28_commit_2_49ed8647345e38270e6362fbb895abc27d7849f9.patch
#
#
#  ******** PushEvent iter 32 ********
# commit 0: https://github.com/2dot71mily/repo_baby/commit/26ddf36ea221b2856901d8f7f26b07872e1276c4
# From 26ddf36ea221b2856901d8f7f26b07872e1276c4 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:06:58 -0700
# Subject: [PATCH] setup
#
# ---
#  .gitignore | 1 +
#  1 file changed, 1 insertion(+)
#  create mode 100644 .gitignore
#
# diff --git a/.gitignore b/.gitignore
# new file mode 100644
# index 0000000..691037e
# --- /dev/null
# +++ b/.gitignore
# @@ -0,0 +1 @@
# +.venv/*
#
# Output written to repo_baby_push_event_32_commit_0_26ddf36ea221b2856901d8f7f26b07872e1276c4.patch

# %% [markdown]
# # PR sub-commits

# %%
# Exracting PR numbers from PullRequestEvents json to find PR sub-commits
unique_pr_numbers = {
    row.payload["number"] for _, row in data_by_type["PullRequestEvent"].iterrows()
}

# %%
for pr in unique_pr_numbers:
    print(f" ******** Processing PR: {pr} ******** ")
    print(f"https://github.com/{owner}/{repo}/pull/{pr}")
    pr_json = get_cleaned_gh_cmd_output(
        pr_commits_cmd_template.format(pr=pr),
        output_filename=pr_output_filename_template.format(pr=pr),
        api_cmd_template=api_cmd_json_template,
    )
    pr_data = json.loads(pr_json)
    for commit in pr_data:
        print(" ****** commit patch ****** ")
        sha = commit["sha"]
        print(f" **** Is commit sha in EventsAPI json? {sha in event_json} **** ")

        print("sha: ", sha)
        print("html_url: ", commit["html_url"])
        get_cleaned_gh_cmd_output(
            commits_cmd_template.format(sha=sha),
            output_filename=commit_output_filename_template.format(
                prefix=f"pr_{pr}", sha=sha
            ),
            api_cmd_template=api_cmd_patch_template,
            verbose=True,
        )

        print(" ****** commit checkrun? ****** ")
        get_cleaned_gh_cmd_output(
            checkruns_cmd_template.format(sha=sha),
            output_filename=checkruns_output_filename_template.format(sha=sha),
            api_cmd_template=api_cmd_json_template,
            verbose=True,
        )
# Out:
#  ******** Processing PR: 1 ********
# https://github.com/2dot71mily/repo_baby/pull/1
#  ****** commit patch ******
#  **** Is commit sha in EventsAPI json? True ****
# sha:  c301e5404dcbd7a693473f9579b12b968c622853
# html_url:  https://github.com/2dot71mily/repo_baby/commit/c301e5404dcbd7a693473f9579b12b968c622853
# From c301e5404dcbd7a693473f9579b12b968c622853 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:08:16 -0700
# Subject: [PATCH] add math
#
# ---
#  math_operations.py | 13 +++++++++++++
#  1 file changed, 13 insertions(+)
#  create mode 100644 math_operations.py
#
# diff --git a/math_operations.py b/math_operations.py
# new file mode 100644
# index 0000000..f7f69b3
# --- /dev/nul
# <truncated>
#
# Output written to repo_baby_pr_1_c301e5404dcbd7a693473f9579b12b968c622853.patch
#
#
#  ****** commit checkrun? ******
# {
#   "total_count": 0,
#   "check_runs": []
# }
#
# Output written to repo_baby_pull_c301e5404dcbd7a693473f9579b12b968c622853_checkruns.json
#
#
#  ****** commit patch ******
#  **** Is commit sha in EventsAPI json? True ****
# sha:  95c67239fa5cb1c47013d2ade665914c947f9d78
# html_url:  https://github.com/2dot71mily/repo_baby/commit/95c67239fa5cb1c47013d2ade665914c947f9d78
# From 95c67239fa5cb1c47013d2ade665914c947f9d78 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:08:25 -0700
# Subject: [PATCH] add math tests
#
# ---
#  test_math_operations.py | 30 ++++++++++++++++++++++++++++++
#  1 file changed, 30 insertions(+)
#  create mode 100644 test_math_operations.py
#
# diff --git a/test_math_operations.py b/test_math_operations.py
# new file mode
# <truncated>
#
# Output written to repo_baby_pr_1_95c67239fa5cb1c47013d2ade665914c947f9d78.patch
#
#
#  ****** commit checkrun? ******
# {
#   "total_count": 0,
#   "check_runs": []
# }
#
# Output written to repo_baby_pull_95c67239fa5cb1c47013d2ade665914c947f9d78_checkruns.json
#
#
#  ******** Processing PR: 2 ********
# https://github.com/2dot71mily/repo_baby/pull/2
#  ****** commit patch ******
#  **** Is commit sha in EventsAPI json? False ****
# sha:  02403767a0877b558fbc19df9450c99e76e4c61b
# html_url:  https://github.com/2dot71mily/repo_baby/commit/02403767a0877b558fbc19df9450c99e76e4c61b
# From 02403767a0877b558fbc19df9450c99e76e4c61b Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:10:35 -0700
# Subject: [PATCH] add list
#
# ---
#  list_operations.py | 10 ++++++++++
#  1 file changed, 10 insertions(+)
#  create mode 100644 list_operations.py
#
# diff --git a/list_operations.py b/list_operations.py
# new file mode 100644
# index 0000000..733eb03
# --- /dev/null
# +
# <truncated>
#
# Output written to repo_baby_pr_2_02403767a0877b558fbc19df9450c99e76e4c61b.patch
#
#
#  ****** commit checkrun? ******
# {
#   "total_count": 0,
#   "check_runs": []
# }
#
# Output written to repo_baby_pull_02403767a0877b558fbc19df9450c99e76e4c61b_checkruns.json
#
#
#  ****** commit patch ******
#  **** Is commit sha in EventsAPI json? True ****
# sha:  9d7f978e7ea315308da8fe2dccf2cf2568a240e2
# html_url:  https://github.com/2dot71mily/repo_baby/commit/9d7f978e7ea315308da8fe2dccf2cf2568a240e2
# From 9d7f978e7ea315308da8fe2dccf2cf2568a240e2 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:10:58 -0700
# Subject: [PATCH] add list tests
#
# ---
#  test_list_operations.py | 25 +++++++++++++++++++++++++
#  1 file changed, 25 insertions(+)
#  create mode 100644 test_list_operations.py
#
# diff --git a/test_list_operations.py b/test_list_operations.py
# new file mode 1006
# <truncated>
#
# Output written to repo_baby_pr_2_9d7f978e7ea315308da8fe2dccf2cf2568a240e2.patch
#
#
#  ****** commit checkrun? ******
# {
#   "total_count": 0,
#   "check_runs": []
# }
#
# Output written to repo_baby_pull_9d7f978e7ea315308da8fe2dccf2cf2568a240e2_checkruns.json
#
#
#  ******** Processing PR: 3 ********
# https://github.com/2dot71mily/repo_baby/pull/3
#  ****** commit patch ******
#  **** Is commit sha in EventsAPI json? True ****
# sha:  73af5f6f8b1ebe50606260b11c7cedd9d65f1b04
# html_url:  https://github.com/2dot71mily/repo_baby/commit/73af5f6f8b1ebe50606260b11c7cedd9d65f1b04
# From 73af5f6f8b1ebe50606260b11c7cedd9d65f1b04 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:18:07 -0700
# Subject: [PATCH] add strings
#
# ---
#  string_operations.py | 10 ++++++++++
#  1 file changed, 10 insertions(+)
#  create mode 100644 string_operations.py
#
# diff --git a/string_operations.py b/string_operations.py
# new file mode 100644
# index 0000000..2c42911
# ---
# <truncated>
#
# Output written to repo_baby_pr_3_73af5f6f8b1ebe50606260b11c7cedd9d65f1b04.patch
#
#
#  ****** commit checkrun? ******
# {
#   "total_count": 0,
#   "check_runs": []
# }
#
# Output written to repo_baby_pull_73af5f6f8b1ebe50606260b11c7cedd9d65f1b04_checkruns.json
#
#
#  ****** commit patch ******
#  **** Is commit sha in EventsAPI json? True ****
# sha:  fe9ef9c93f7415d790def19e43090bb213e3db44
# html_url:  https://github.com/2dot71mily/repo_baby/commit/fe9ef9c93f7415d790def19e43090bb213e3db44
# From fe9ef9c93f7415d790def19e43090bb213e3db44 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:18:18 -0700
# Subject: [PATCH] add strings tests
#
# ---
#  test_string_operations.py | 22 ++++++++++++++++++++++
#  1 file changed, 22 insertions(+)
#  create mode 100644 test_string_operations.py
#
# diff --git a/test_string_operations.py b/test_string_operations.py
# new file m
# <truncated>
#
# Output written to repo_baby_pr_3_fe9ef9c93f7415d790def19e43090bb213e3db44.patch
#
#
#  ****** commit checkrun? ******
# {
#   "total_count": 0,
#   "check_runs": []
# }
#
# Output written to repo_baby_pull_fe9ef9c93f7415d790def19e43090bb213e3db44_checkruns.json
#
#
#  ******** Processing PR: 4 ********
# https://github.com/2dot71mily/repo_baby/pull/4
#  ****** commit patch ******
#  **** Is commit sha in EventsAPI json? False ****
# sha:  2fd7c7f721458a60f7287c75d319eb8c0cb06e9b
# html_url:  https://github.com/2dot71mily/repo_baby/commit/2fd7c7f721458a60f7287c75d319eb8c0cb06e9b
# From 2fd7c7f721458a60f7287c75d319eb8c0cb06e9b Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:22:56 -0700
# Subject: [PATCH] add docker file
#
# ---
#  docker/dockerfile | 5 +++++
#  1 file changed, 5 insertions(+)
#  create mode 100644 docker/dockerfile
#
# diff --git a/docker/dockerfile b/docker/dockerfile
# new file mode 100644
# index 0000000..bd1d6c6
# --- /dev/null
# +++ b
# <truncated>
#
# Output written to repo_baby_pr_4_2fd7c7f721458a60f7287c75d319eb8c0cb06e9b.patch
#
#
#  ****** commit checkrun? ******
# {
#   "total_count": 0,
#   "check_runs": []
# }
#
# Output written to repo_baby_pull_2fd7c7f721458a60f7287c75d319eb8c0cb06e9b_checkruns.json
#
#
#  ****** commit patch ******
#  **** Is commit sha in EventsAPI json? False ****
# sha:  207a4028fa7176c869f3816b143fb1ada51a10ac
# html_url:  https://github.com/2dot71mily/repo_baby/commit/207a4028fa7176c869f3816b143fb1ada51a10ac
# From 207a4028fa7176c869f3816b143fb1ada51a10ac Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:23:12 -0700
# Subject: [PATCH] add docker compose
#
# ---
#  docker/docker-compose.yaml | 4 ++++
#  1 file changed, 4 insertions(+)
#  create mode 100644 docker/docker-compose.yaml
#
# diff --git a/docker/docker-compose.yaml b/docker/docker-compose.yaml
# new file mode 100644
# inde
# <truncated>
#
# Output written to repo_baby_pr_4_207a4028fa7176c869f3816b143fb1ada51a10ac.patch
#
#
#  ****** commit checkrun? ******
# {
#   "total_count": 0,
#   "check_runs": []
# }
#
# Output written to repo_baby_pull_207a4028fa7176c869f3816b143fb1ada51a10ac_checkruns.json
#
#
#  ****** commit patch ******
#  **** Is commit sha in EventsAPI json? False ****
# sha:  5bdb9b155e27193208056f293e29788c3bb3a163
# html_url:  https://github.com/2dot71mily/repo_baby/commit/5bdb9b155e27193208056f293e29788c3bb3a163
# From 5bdb9b155e27193208056f293e29788c3bb3a163 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:23:24 -0700
# Subject: [PATCH] add docker readme
#
# ---
#  docker/README.md | 39 +++++++++++++++++++++++++++++++++++++++
#  1 file changed, 39 insertions(+)
#  create mode 100644 docker/README.md
#
# diff --git a/docker/README.md b/docker/README.md
# new file mode 100644
# index 00
# <truncated>
#
# Output written to repo_baby_pr_4_5bdb9b155e27193208056f293e29788c3bb3a163.patch
#
#
#  ****** commit checkrun? ******
# {
#   "total_count": 0,
#   "check_runs": []
# }
#
# Output written to repo_baby_pull_5bdb9b155e27193208056f293e29788c3bb3a163_checkruns.json
#
#
#  ****** commit patch ******
#  **** Is commit sha in EventsAPI json? True ****
# sha:  c86315ccfa145f10638c6c976d1a440cf4226ad5
# html_url:  https://github.com/2dot71mily/repo_baby/commit/c86315ccfa145f10638c6c976d1a440cf4226ad5
# From c86315ccfa145f10638c6c976d1a440cf4226ad5 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:23:32 -0700
# Subject: [PATCH] mod gitignore
#
# ---
#  .gitignore | 1 +
#  1 file changed, 1 insertion(+)
#
# diff --git a/.gitignore b/.gitignore
# index 691037e..26be7c1 100644
# --- a/.gitignore
# +++ b/.gitignore
# @@ -1 +1,2 @@
#  .venv/*
# +.DS_Store
#
# Output written to repo_baby_pr_4_c86315ccfa145f10638c6c976d1a440cf4226ad5.patch
#
#
#  ****** commit checkrun? ******
# {
#   "total_count": 0,
#   "check_runs": []
# }
#
# Output written to repo_baby_pull_c86315ccfa145f10638c6c976d1a440cf4226ad5_checkruns.json
#
#
#  ******** Processing PR: 5 ********
# https://github.com/2dot71mily/repo_baby/pull/5
#  ****** commit patch ******
#  **** Is commit sha in EventsAPI json? False ****
# sha:  50c64c472a3e928c353fd9f59a3140c7d06ff620
# html_url:  https://github.com/2dot71mily/repo_baby/commit/50c64c472a3e928c353fd9f59a3140c7d06ff620
# From 50c64c472a3e928c353fd9f59a3140c7d06ff620 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:39:03 -0700
# Subject: [PATCH] add gh event data
#
# ---
#  gh_data/repo_baby_events.json | 3454 +++++++++++++++++++++++++++++++++
#  1 file changed, 3454 insertions(+)
#  create mode 100644 gh_data/repo_baby_events.json
#
# diff --git a/gh_data/repo_baby_events.json b/gh_data/r
# <truncated>
#
# Output written to repo_baby_pr_5_50c64c472a3e928c353fd9f59a3140c7d06ff620.patch
#
#
#  ****** commit checkrun? ******
# {
#   "total_count": 0,
#   "check_runs": []
# }
#
# Output written to repo_baby_pull_50c64c472a3e928c353fd9f59a3140c7d06ff620_checkruns.json
#
#
#  ****** commit patch ******
#  **** Is commit sha in EventsAPI json? False ****
# sha:  350afeb0672d753804dcb1c531e6c4f0ddbf5763
# html_url:  https://github.com/2dot71mily/repo_baby/commit/350afeb0672d753804dcb1c531e6c4f0ddbf5763
# From 350afeb0672d753804dcb1c531e6c4f0ddbf5763 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:39:20 -0700
# Subject: [PATCH] add gh pr commits data
#
# ---
#  gh_data/repo_baby_pr4_commits.json | 1 +
#  1 file changed, 1 insertion(+)
#  create mode 100644 gh_data/repo_baby_pr4_commits.json
#
# diff --git a/gh_data/repo_baby_pr4_commits.json b/gh_data/repo_baby_pr4_commit
# <truncated>
#
# Output written to repo_baby_pr_5_350afeb0672d753804dcb1c531e6c4f0ddbf5763.patch
#
#
#  ****** commit checkrun? ******
# {
#   "total_count": 0,
#   "check_runs": []
# }
#
# Output written to repo_baby_pull_350afeb0672d753804dcb1c531e6c4f0ddbf5763_checkruns.json
#
#
#  ****** commit patch ******
#  **** Is commit sha in EventsAPI json? True ****
# sha:  de097b254ae98da990f0d1617446ce595f041f22
# html_url:  https://github.com/2dot71mily/repo_baby/commit/de097b254ae98da990f0d1617446ce595f041f22
# From de097b254ae98da990f0d1617446ce595f041f22 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:39:31 -0700
# Subject: [PATCH] add gh readme
#
# ---
#  gh_data/README.md | 25 +++++++++++++++++++++++++
#  1 file changed, 25 insertions(+)
#  create mode 100644 gh_data/README.md
#
# diff --git a/gh_data/README.md b/gh_data/README.md
# new file mode 100644
# index 0000000..c538337
# <truncated>
#
# Output written to repo_baby_pr_5_de097b254ae98da990f0d1617446ce595f041f22.patch
#
#
#  ****** commit checkrun? ******
# {
#   "total_count": 0,
#   "check_runs": []
# }
#
# Output written to repo_baby_pull_de097b254ae98da990f0d1617446ce595f041f22_checkruns.json
#
#
#  ******** Processing PR: 6 ********
# https://github.com/2dot71mily/repo_baby/pull/6
#  ****** commit patch ******
#  **** Is commit sha in EventsAPI json? True ****
# sha:  8a9060cd91184699b05dbccde30f66a3aa51beae
# html_url:  https://github.com/2dot71mily/repo_baby/commit/8a9060cd91184699b05dbccde30f66a3aa51beae
# From 8a9060cd91184699b05dbccde30f66a3aa51beae Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Thu, 22 Aug 2024 23:43:09 -0700
# Subject: [PATCH] mod readme
#
# ---
#  README.md | 9 +++++++++
#  1 file changed, 9 insertions(+)
#
# diff --git a/README.md b/README.md
# index 8bc8734..b608cb0 100644
# --- a/README.md
# +++ b/README.md
# @@ -1 +1,10 @@
#  # repo_baby
# +
# +This main dir is function & unitt
# <truncated>
#
# Output written to repo_baby_pr_6_8a9060cd91184699b05dbccde30f66a3aa51beae.patch
#
#
#  ****** commit checkrun? ******
# {
#   "total_count": 0,
#   "check_runs": []
# }
#
# Output written to repo_baby_pull_8a9060cd91184699b05dbccde30f66a3aa51beae_checkruns.json
#
#
#  ******** Processing PR: 7 ********
# https://github.com/2dot71mily/repo_baby/pull/7
#  ****** commit patch ******
#  **** Is commit sha in EventsAPI json? True ****
# sha:  f2af16a103f445845fc59ca5ad126789f1356cde
# html_url:  https://github.com/2dot71mily/repo_baby/commit/f2af16a103f445845fc59ca5ad126789f1356cde
# From f2af16a103f445845fc59ca5ad126789f1356cde Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 21:17:39 -0700
# Subject: [PATCH] add workflow
#
# ---
#  .github/workflows/python-app.yml | 39 ++++++++++++++++++++++++++++++++
#  1 file changed, 39 insertions(+)
#  create mode 100644 .github/workflows/python-app.yml
#
# diff --git a/.github/workflows/python-app.yml b/.github/wo
# <truncated>
#
# Output written to repo_baby_pr_7_f2af16a103f445845fc59ca5ad126789f1356cde.patch
#
#
#  ****** commit checkrun? ******
# {
#   "total_count": 1,
#   "check_runs": [
#     {
#       "id": 29233875584,
#       "name": "build",
#       "node_id": "CR_kwDOMnMKmM8AAAAGznmKgA",
#       "head_sha": "f2af16a103f445845fc59ca5ad126789f1356cde",
#       "external_id": "ca395085-040a-526b-2ce8-bdc85f692774",
#       "url": "https://api.github.com/repos/2dot71mily/repo_baby/check-runs/29233875584",
#       "html_url": "https://github.com/2dot71mily
# <truncated>
#
# Output written to repo_baby_pull_f2af16a103f445845fc59ca5ad126789f1356cde_checkruns.json
#
#
#  ****** commit patch ******
#  **** Is commit sha in EventsAPI json? True ****
# sha:  3f559e1ec3cfb480b039e95867c552b9f7a10627
# html_url:  https://github.com/2dot71mily/repo_baby/commit/3f559e1ec3cfb480b039e95867c552b9f7a10627
# From 3f559e1ec3cfb480b039e95867c552b9f7a10627 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 21:22:23 -0700
# Subject: [PATCH] add logistic regression
#
# ---
#  logistic_regression.py | 34 ++++++++++++++++++++++++++++++++++
#  1 file changed, 34 insertions(+)
#  create mode 100644 logistic_regression.py
#
# diff --git a/logistic_regression.py b/logistic_regression.py
# new
# <truncated>
#
# Output written to repo_baby_pr_7_3f559e1ec3cfb480b039e95867c552b9f7a10627.patch
#
#
#  ****** commit checkrun? ******
# {
#   "total_count": 0,
#   "check_runs": []
# }
#
# Output written to repo_baby_pull_3f559e1ec3cfb480b039e95867c552b9f7a10627_checkruns.json
#
#
#  ****** commit patch ******
#  **** Is commit sha in EventsAPI json? True ****
# sha:  a81a26b8c4308e476ebbeaeded202b86e7fe9877
# html_url:  https://github.com/2dot71mily/repo_baby/commit/a81a26b8c4308e476ebbeaeded202b86e7fe9877
# From a81a26b8c4308e476ebbeaeded202b86e7fe9877 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 21:22:36 -0700
# Subject: [PATCH] add test logistic regression
#
# ---
#  test_logistic_regression.py | 33 +++++++++++++++++++++++++++++++++
#  1 file changed, 33 insertions(+)
#  create mode 100644 test_logistic_regression.py
#
# diff --git a/test_logistic_regression.py b/test_log
# <truncated>
#
# Output written to repo_baby_pr_7_a81a26b8c4308e476ebbeaeded202b86e7fe9877.patch
#
#
#  ****** commit checkrun? ******
# {
#   "total_count": 1,
#   "check_runs": [
#     {
#       "id": 29233923957,
#       "name": "build",
#       "node_id": "CR_kwDOMnMKmM8AAAAGznpHdQ",
#       "head_sha": "a81a26b8c4308e476ebbeaeded202b86e7fe9877",
#       "external_id": "ca395085-040a-526b-2ce8-bdc85f692774",
#       "url": "https://api.github.com/repos/2dot71mily/repo_baby/check-runs/29233923957",
#       "html_url": "https://github.com/2dot71mily
# <truncated>
#
# Output written to repo_baby_pull_a81a26b8c4308e476ebbeaeded202b86e7fe9877_checkruns.json
#
#
#  ****** commit patch ******
#  **** Is commit sha in EventsAPI json? True ****
# sha:  5dc0480ed997d2bfeb40e79de900e71e097632b4
# html_url:  https://github.com/2dot71mily/repo_baby/commit/5dc0480ed997d2bfeb40e79de900e71e097632b4
# From 5dc0480ed997d2bfeb40e79de900e71e097632b4 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 21:31:01 -0700
# Subject: [PATCH] add e2e
#
# ---
#  e2e_logistic_regression.py | 46 ++++++++++++++++++++++++++++++++++++++
#  1 file changed, 46 insertions(+)
#  create mode 100644 e2e_logistic_regression.py
#
# diff --git a/e2e_logistic_regression.py b/e2e_logistic_regression.py
#
# <truncated>
#
# Output written to repo_baby_pr_7_5dc0480ed997d2bfeb40e79de900e71e097632b4.patch
#
#
#  ****** commit checkrun? ******
# {
#   "total_count": 0,
#   "check_runs": []
# }
#
# Output written to repo_baby_pull_5dc0480ed997d2bfeb40e79de900e71e097632b4_checkruns.json
#
#
#  ****** commit patch ******
#  **** Is commit sha in EventsAPI json? True ****
# sha:  58f63591312000428772626e100c6c801d0d4ea0
# html_url:  https://github.com/2dot71mily/repo_baby/commit/58f63591312000428772626e100c6c801d0d4ea0
# From 58f63591312000428772626e100c6c801d0d4ea0 Mon Sep 17 00:00:00 2001
# From: emily <emily.mcmilin@gmail.com>
# Date: Sun, 25 Aug 2024 21:31:11 -0700
# Subject: [PATCH] add e2e test
#
# ---
#  test_e2e_logistic_regression.py | 6 ++++++
#  1 file changed, 6 insertions(+)
#  create mode 100644 test_e2e_logistic_regression.py
#
# diff --git a/test_e2e_logistic_regression.py b/test_e2e_logistic_regression.py
# new file
# <truncated>
#
# Output written to repo_baby_pr_7_58f63591312000428772626e100c6c801d0d4ea0.patch
#
#
#  ****** commit checkrun? ******
# {
#   "total_count": 1,
#   "check_runs": [
#     {
#       "id": 29234108109,
#       "name": "build",
#       "node_id": "CR_kwDOMnMKmM8AAAAGzn0WzQ",
#       "head_sha": "58f63591312000428772626e100c6c801d0d4ea0",
#       "external_id": "ca395085-040a-526b-2ce8-bdc85f692774",
#       "url": "https://api.github.com/repos/2dot71mily/repo_baby/check-runs/29234108109",
#       "html_url": "https://github.com/2dot71mily
# <truncated>
#
# Output written to repo_baby_pull_58f63591312000428772626e100c6c801d0d4ea0_checkruns.json
